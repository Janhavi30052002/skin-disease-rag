# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(project_root)
# Out:
# c:\Users\janha\OneDrive\Desktop\skin-disease-rag

# %%
import pandas as pd

from models.dataset import HAMDataset
from models.transforms import train_transform

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# c:\Users\janha\OneDrive\Desktop\skin-disease-rag\notebooks

# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve().parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print("Project Root:", project_root)
# Out:
# Project Root: C:\Users\janha\OneDrive\Desktop\skin-disease-rag

# %%
import models

print(models.__file__)
# Out:
# c:\Users\janha\OneDrive\Desktop\skin-disease-rag\models\__init__.py

# %%
train_df = pd.read_csv(
    "../data/metadata/train.csv"
)

dataset = HAMDataset(
    train_df,
    train_transform
)

image, label = dataset[0]

print(image.shape)
print(label)
# Out:
# torch.Size([3, 224, 224])
# 2
